# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Conv2D, MaxPooling2D, Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import to_categorical
from tensorflow.keras import regularizers
from tensorflow.keras.datasets import fashion_mnist

# %%
(x_train, y_train), (x_test, y_test) = fashion_mnist.load_data()

# %%
x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.

num_classes = 10
y_train = to_categorical(y_train, num_classes)
y_test = to_categorical(y_test, num_classes)

# %%
x_train = x_train.reshape((60000, 28, 28, 1))
x_test = x_test.reshape((10000, 28, 28, 1))

# %%
plt.figure(figsize=(16, 6))
for i in range(10):
    plt.subplot(2, 5, i+1)
    img = x_train[i]
    plt.imshow(img, cmap='gray')
    plt.title("Class: " + str(i), c='g')   
plt.show()

# %%
model = Sequential(name='fashion_mnist')
model.add(Conv2D(filters=32, kernel_size=2, padding='same', activation='relu', input_shape=(28,28,1)))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.4))
model.add(Conv2D(filters=64, kernel_size=2, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.4))
model.add(BatchNormalization())

model.add(Flatten())
model.add(Dense(512, activation='relu', kernel_regularizer=regularizers.l2(0.0001), name='hidden_1'))
model.add(Dropout(0.3))
model.add(Dense(256, activation='relu', kernel_regularizer=regularizers.l2(0.0001), name='hidden_2'))
model.add(Dropout(0.2))
model.add(Dense(10, activation='softmax', name='output'))

# %%
model.summary()
# Out:
# Model: "fashion_mnist"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 28, 28, 32)        160
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 14, 14, 32)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 14, 14, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 14, 14, 64)        8256
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 7, 7, 64)          0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 7, 7, 64)          0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 7, 7, 64)          256
# _________________________________________________________________
# flatten (Flatten)            (None, 3136)              0
# _________________________________________________________________
# hidden_1 (Dense)             (None, 512)               1606144
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# hidden_2 (Dense)             (None, 256)               131328
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 256)               0
# _________________________________________________________________
# output (Dense)               (None, 10)                2570
# =================================================================
# Total params: 1,748,714
# Trainable params: 1,748,586
# Non-trainable params: 128
# _________________________________________________________________

# %%
# Compile model
model.compile(loss='categorical_crossentropy',
              optimizer=Adam(learning_rate=0.0005),
              metrics=['accuracy'])

#Train model
history = model.fit(x_train, y_train,
                    batch_size=256,
                    epochs=54,
                    verbose=1,
                    validation_data=(x_test, y_test))

# Evaluate model
test_loss, test_acc = model.evaluate(x_test, y_test, verbose=0)
print('Test accuracy:', test_acc)
# Out:
# Epoch 1/54
# 235/235 [==============================] - 4s 17ms/step - loss: 0.8172 - accuracy: 0.7399 - val_loss: 1.2038 - val_accuracy: 0.8270
# Epoch 2/54
# 235/235 [==============================] - 4s 16ms/step - loss: 0.5762 - accuracy: 0.8307 - val_loss: 0.5672 - val_accuracy: 0.8605
# Epoch 3/54
# 235/235 [==============================] - 4s 15ms/step - loss: 0.5066 - accuracy: 0.8568 - val_loss: 0.4683 - val_accuracy: 0.8702
# Epoch 4/54
# 235/235 [==============================] - 4s 17ms/step - loss: 0.4709 - accuracy: 0.8698 - val_loss: 0.4411 - val_accuracy: 0.8820
# Epoch 5/54
# 235/235 [==============================] - 4s 17ms/step - loss: 0.4380 - accuracy: 0.8807 - val_loss: 0.4231 - val_accuracy: 0.8859
# Epoch 6/54
# 235/235 [==============================] - 4s 18ms/step - loss: 0.4135 - accuracy: 0.8885 - val_loss: 0.3900 - val_accuracy: 0.8973
# Epoch 7/54
# 235/235 [==============================] - 4s 17ms/step - loss: 0.3954 - accuracy: 0.8946 - val_loss: 0.3720 - val_accuracy: 0.8989
# Epoch 8/54
# 235/235 [==============================] - 4s 18ms/step - loss: 0.3827 - accuracy: 0.8978 - val_loss: 0.3687 - val_accuracy: 0.9052
# Epoch 9/54
# 235/235 [==============================] - 5s 20ms/step - loss: 0.3687 - accuracy: 0.9012 - val_loss: 0.3498 - val_accuracy: 0.9106
# Epoch 10/54
# 235/235 [==============================] - 4s 19ms/step - loss: 0.3574 - accuracy: 0.9056 - val_loss: 0.3451 - val_accuracy: 0.9066
# Epoch 11/54
# 235/235 [==============================] - 4s 17ms/step - loss: 0.3460 - accuracy: 0.9082 - val_loss: 0.3347 - val_accuracy: 0.9146
# Epoch 12/54
# 235/235 [==============================] - 4s 18ms/step - loss: 0.3375 - accuracy: 0.9104 - val_loss: 0.3398 - val_accuracy: 0.9103
# Epoch 13/54
# 235/235 [==============================] - 4s 17ms/step - loss: 0.3293 - accuracy: 0.9119 - val_loss: 0.3244 - val_accuracy: 0.9139
# Epoch 14/54
# 235/235 [==============================] - 4s 17ms/step - loss: 0.3219 - accuracy: 0.9149 - val_loss: 0.3264 - val_accuracy: 0.9148
# Epoch 15/54
# 235/235 [==============================] - 4s 18ms/step - loss: 0.3174 - accuracy: 0.9164 - val_loss: 0.3219 - val_accuracy: 0.9166
# Epoch 16/54
# 235/235 [==============================] - 4s 18ms/step - loss: 0.3114 - accuracy: 0.9173 - val_loss: 0.3326 - val_accuracy: 0.9146
# Epoch 17/54
# 235/235 [==============================] - 4s 18ms/step - loss: 0.3053 - accuracy: 0.9195 - val_loss: 0.3168 - val_accuracy: 0.9202
# Epoch 18/54
# 235/235 [==============================] - 4s 19ms/step - loss: 0.2972 - accuracy: 0.9231 - val_loss: 0.3131 - val_accuracy: 0.9204
# Epoch 19/54
# 235/235 [==============================] - 4s 18ms/step - loss: 0.2958 - accuracy: 0.9240 - val_loss: 0.3228 - val_accuracy: 0.9181
# Epoch 20/54
# 235/235 [==============================] - 4s 19ms/step - loss: 0.2940 - accuracy: 0.9231 - val_loss: 0.3192 - val_accuracy: 0.9208
# Epoch 21/54
# 235/235 [==============================] - 4s 18ms/step - loss: 0.2914 - accuracy: 0.9240 - val_loss: 0.3122 - val_accuracy: 0.9222
# Epoch 22/54
# 235/235 [==============================] - 4s 18ms/step - loss: 0.2852 - accuracy: 0.9271 - val_loss: 0.3176 - val_accuracy: 0.9200
# Epoch 23/54
# 235/235 [==============================] - 4s 18ms/step - loss: 0.2821 - accuracy: 0.9285 - val_loss: 0.3057 - val_accuracy: 0.9230
# Epoch 24/54
# 235/235 [==============================] - 4s 18ms/step - loss: 0.2783 - accuracy: 0.9299 - val_loss: 0.2928 - val_accuracy: 0.9289
# Epoch 25/54
# 235/235 [==============================] - 4s 18ms/step - loss: 0.2766 - accuracy: 0.9299 - val_loss: 0.2996 - val_accuracy: 0.9267
# Epoch 26/54
# 235/235 [==============================] - 4s 18ms/step - loss: 0.2763 - accuracy: 0.9312 - val_loss: 0.3157 - val_accuracy: 0.9227
# Epoch 27/54
# 235/235 [==============================] - 4s 17ms/step - loss: 0.2744 - accuracy: 0.9317 - val_loss: 0.3072 - val_accuracy: 0.9245
# Epoch 28/54
# 235/235 [==============================] - 4s 17ms/step - loss: 0.2693 - accuracy: 0.9328 - val_loss: 0.3156 - val_accuracy: 0.9232
# Epoch 29/54
# 235/235 [==============================] - 4s 18ms/step - loss: 0.2701 - accuracy: 0.9336 - val_loss: 0.3002 - val_accuracy: 0.9259
# Epoch 30/54
# 235/235 [==============================] - 4s 18ms/step - loss: 0.2695 - accuracy: 0.9343 - val_loss: 0.2977 - val_accuracy: 0.9267
# Epoch 31/54
# 235/235 [==============================] - 4s 17ms/step - loss: 0.2635 - accuracy: 0.9361 - val_loss: 0.3049 - val_accuracy: 0.9284
# Epoch 32/54
# 235/235 [==============================] - 4s 17ms/step - loss: 0.2648 - accuracy: 0.9367 - val_loss: 0.3094 - val_accuracy: 0.9272
# Epoch 33/54
# 235/235 [==============================] - 4s 18ms/step - loss: 0.2610 - accuracy: 0.9384 - val_loss: 0.3075 - val_accuracy: 0.9286
# Epoch 34/54
# 235/235 [==============================] - 4s 19ms/step - loss: 0.2607 - accuracy: 0.9385 - val_loss: 0.3187 - val_accuracy: 0.9247
# Epoch 35/54
# 235/235 [==============================] - 4s 18ms/step - loss: 0.2605 - accuracy: 0.9378 - val_loss: 0.3023 - val_accuracy: 0.9300
# Epoch 36/54
# 235/235 [==============================] - 4s 18ms/step - loss: 0.2596 - accuracy: 0.9394 - val_loss: 0.3032 - val_accuracy: 0.9284
# Epoch 37/54
# 235/235 [==============================] - 4s 17ms/step - loss: 0.2583 - accuracy: 0.9389 - val_loss: 0.3016 - val_accuracy: 0.9289
# Epoch 38/54
# 235/235 [==============================] - 4s 18ms/step - loss: 0.2554 - accuracy: 0.9408 - val_loss: 0.3314 - val_accuracy: 0.9210
# Epoch 39/54
# 235/235 [==============================] - 4s 18ms/step - loss: 0.2556 - accuracy: 0.9407 - val_loss: 0.3064 - val_accuracy: 0.9282
# Epoch 40/54
# 235/235 [==============================] - 4s 17ms/step - loss: 0.2542 - accuracy: 0.9409 - val_loss: 0.3096 - val_accuracy: 0.9287
# Epoch 41/54
# 235/235 [==============================] - 4s 17ms/step - loss: 0.2554 - accuracy: 0.9415 - val_loss: 0.2993 - val_accuracy: 0.9314
# Epoch 42/54
# 235/235 [==============================] - 4s 17ms/step - loss: 0.2530 - accuracy: 0.9428 - val_loss: 0.3110 - val_accuracy: 0.9287
# Epoch 43/54
# 235/235 [==============================] - 4s 17ms/step - loss: 0.2506 - accuracy: 0.9442 - val_loss: 0.3143 - val_accuracy: 0.9274
# Epoch 44/54
# 235/235 [==============================] - 4s 18ms/step - loss: 0.2499 - accuracy: 0.9442 - val_loss: 0.3085 - val_accuracy: 0.9282
# Epoch 45/54
# 235/235 [==============================] - 4s 17ms/step - loss: 0.2512 - accuracy: 0.9438 - val_loss: 0.3026 - val_accuracy: 0.9330
# Epoch 46/54
# 235/235 [==============================] - 4s 17ms/step - loss: 0.2476 - accuracy: 0.9448 - val_loss: 0.3114 - val_accuracy: 0.9300
# Epoch 47/54
# 235/235 [==============================] - 4s 18ms/step - loss: 0.2492 - accuracy: 0.9438 - val_loss: 0.3092 - val_accuracy: 0.9287
# Epoch 48/54
# 235/235 [==============================] - 4s 17ms/step - loss: 0.2499 - accuracy: 0.9447 - val_loss: 0.3075 - val_accuracy: 0.9299
# Epoch 49/54
# 235/235 [==============================] - 4s 17ms/step - loss: 0.2482 - accuracy: 0.9453 - val_loss: 0.3064 - val_accuracy: 0.9315
# Epoch 50/54
# 235/235 [==============================] - 4s 17ms/step - loss: 0.2451 - accuracy: 0.9458 - val_loss: 0.3148 - val_accuracy: 0.9281
# Epoch 51/54
# 235/235 [==============================] - 4s 17ms/step - loss: 0.2463 - accuracy: 0.9468 - val_loss: 0.3127 - val_accuracy: 0.9302
# Epoch 52/54
# 235/235 [==============================] - 4s 17ms/step - loss: 0.2442 - accuracy: 0.9470 - val_loss: 0.3193 - val_accuracy: 0.9269
# Epoch 53/54
# 235/235 [==============================] - 4s 17ms/step - loss: 0.2443 - accuracy: 0.9479 - val_loss: 0.3178 - val_accuracy: 0.9294
# Epoch 54/54
# 235/235 [==============================] - 4s 17ms/step - loss: 0.2457 - accuracy: 0.9473 - val_loss: 0.3086 - val_accuracy: 0.9323
# Test accuracy: 0.9322999715805054

# %%
history_dict = history.history
loss_values = history_dict['loss']
val_loss_values = history_dict['val_loss']

epochs = range(1, len(history_dict['accuracy']) + 1)

plt.rcParams["figure.figsize"] = (16, 8)
plt.plot(epochs, loss_values, 'go', label='Training loss')
plt.plot(epochs, val_loss_values, 'g', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid()
plt.show()

plt.plot(epochs, history_dict['accuracy'], 'go', label='Training acc')
plt.plot(epochs, history_dict['val_accuracy'], 'g', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# Загалом, згорткові мережі мають здатність до здійснення більш точної класифікації зображень, оскільки вони здатні виявляти локальні залежності в даних, які можуть бути недоступні для багатошарових мереж. Таким чином, краще підходять для задач обробки зображень, розпізнавання об'єктів або класифікація зображень.
